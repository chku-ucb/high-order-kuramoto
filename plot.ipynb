# %%
using Pkg
Pkg.activate("env")
# Out:
#   Activating project at `~/Library/CloudStorage/OneDrive-UCB-O365/dissertation/high-order-kuramoto/env`

# %%
using Plots, JLD2

# %%
@load "res_n_20000_ID_552333_rK3_0.5.jld2"
# Out:
# 9-element Vector{Symbol}:
#  :k2rf
#  :R_tatf
#  :R_fdaf
#  :Rf_num
#  :k2rb
#  :R_tatb
#  :R_fdab
#  :Rb_num
#  :key_params

# %%
key_params
# Out:
# Dict{String, Any} with 8 entries:
#   "n"           => 20000
#   "K2Crit"      => 0.00379528
#   "Mean_deg"    => 499.504
#   "K3Crit_mean" => 0.00206051
#   "Mean_deg3"   => 500.155
#   "K2Crit_mean" => 0.0037955
#   "target_deg"  => [430, 520, 387, 658, 441, 458, 682, 619, 498, 600  …  639, 4…
#   "K3Crit"      => 0.00207773

# %%
plot(k2rf, Rf_num,ls = :solid,c=:blue, label="Num",xlabel="K2/K2crit", ylabel="R2",title = "N=20k, K3=0.5K3crit",dpi=300)
plot!(k2rb, Rb_num, ls = :dash,c=:blue, label="")
plot!(k2rf, R_tatf, ls = :solid,c=:red, label="Tat")
plot!(k2rb, R_tatb, ls = :dash,c=:red, label="")
plot!(k2rf, R_fdaf, ls = :solid,c=:green, label="Fda")
plot!(k2rb, R_fdab, ls = :dash,c=:green, label="")
savefig("/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_high_order_n20000_k3_0.5.pdf")
# Out:
# "/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_high_order_n20000_k3_0.5.pdf"

# %%
@load "res_n_20000_ID_552333_rK3_2.5.jld2"
plot(k2rf, Rf_num,ls = :solid,c=:blue, label="Num",xlabel="K2/K2crit", ylabel="R2",title = "N=20k, K3=2.5K3crit")
plot!(k2rb, Rb_num, ls = :dash,c=:blue, label="")
plot!(k2rf, R_tatf, ls = :solid,c=:red, label="Tat")
plot!(k2rb, R_tatb, ls = :dash,c=:red, label="")
plot!(k2rf, R_fdaf, ls = :solid,c=:green, label="Fda")
plot!(k2rb, R_fdab, ls = :dash,c=:green, label="")
savefig("/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_high_order_n20000_k3_2.5.pdf")
# Out:
# "/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_high_order_n20000_k3_2.5.pdf"

# %%
@load "results/res_n_20000_ID_552333_rK3_2.0.jld2"
plot(k2rf, Rf_num,ls = :solid,c=:blue)
plot!(k2rb, Rb_num, ls = :dash,c=:blue)
plot!(k2rf, R_tatf, ls = :solid,c=:red)
plot!(k2rb, R_tatb, ls = :dash,c=:red)
plot!(k2rf, R_fdaf, ls = :solid,c=:green)
plot!(k2rb, R_fdab, ls = :dash,c=:green)

# %%
@load "rewiring_3D_Ω_increase_ID_142525.jld2"
# Out:
# 15-element Vector{Symbol}:
#  :k2rf
#  :R_tatf
#  :R_tatpf
#  :R_fdaf
#  :R_fdapf
#  :k2rb
#  :R_tatb
#  :R_tatpb
#  :R_fdab
#  :R_fdapb
#  :Rf_num
#  :Rb_num
#  :Rf_nump
#  :Rb_nump
#  :keyparams

# %%
@load "rewiring_3D_Ω_decrease_ID_320268.jld2"
plot(k2rf, Rf_num,ls = :solid,c=:blue)
plot!(k2rb, Rb_num, ls = :dash,c=:blue)
plot!(k2rf, Rf_nump,ls = :solid,c=:black)
plot!(k2rb, Rb_nump, ls = :dash,c=:black)
# plot!(k2rf, R_tatpf, ls = :solid,c=:red)
# plot!(k2rb, R_tatpb, ls = :dash,c=:red)
# plot!(k2rf, R_fdapf, ls = :solid,c=:green)
# plot!(k2rb, R_fdapb, ls = :dash,c=:green)
# plot!(k2rf, R_fdaf, ls = :solid,c=:orange)
# plot!(k2rb, R_fdab, ls = :dash,c=:orange)
# plot!(k2rf, R_tatf, ls = :solid,c=:purple)
# plot!(k2rb, R_tatb, ls = :dash,c=:purple)

# %%
keyparams
# Out:
# Dict{String, Real} with 7 entries:
#   "K2Critp"  => 0.00822648
#   "K2Crit"   => 0.00822648
#   "max_deg"  => 400
#   "mean_deg" => 100
#   "min_deg"  => 50
#   "K3Critp"  => 0.0273793
#   "K3Crit"   => 0.00690692

# %%
@load "rewiring_3D_Ω_increase_ID_399391_N_4000.jld2"

plot(k2rf, Rf_nump,ls = :solid,c=:black,label="Num",dpi=300,xlabel="K2/K2crit", ylabel="R2",title = "Rewire N=4k, Increase, K3=2.5K3crit_orig")
plot!(k2rb, Rb_nump, ls = :dash,c=:black,label="")
plot!(k2rf, R_tatpf, ls = :solid,c=:red,label="Tat")
plot!(k2rb, R_tatpb, ls = :dash,c=:red,label="")
plot!(k2rf, R_fdapf, ls = :solid,c=:green,label="Fda")
plot!(k2rb, R_fdapb, ls = :dash,c=:green,label="")
savefig("/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_rewire_increase_n4000_k3_2.5.pdf")
# Out:
# "/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_rewire_increase_n4000_k3_2.5.pdf"

# %%
p = plot(k2rf, Rf_num,ls = :solid,c=:black,label="Num",dpi=300,xlabel="K2/K2crit", ylabel="R2",title = "Rewire N=4k, Orig_inc, K3=2.5K3crit_orig")
plot!(k2rb, Rb_num, ls = :dash,c=:black,label="")
plot!(k2rf, R_tatf, ls = :solid,c=:red,label="Tat")
plot!(k2rb, R_tatb, ls = :dash,c=:red,label="")
plot!(k2rf, R_fdaf, ls = :solid,c=:green,label="Fda")
plot!(k2rb, R_fdab, ls = :dash,c=:green,label="")
savefig("/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_orig_increase_n4000_k3_2.5.pdf")
display(p)

# %%
plot(k2rf, R_tatpf, ls = :solid,c=:red)
plot!(k2rb, R_tatpb, ls = :dash,c=:red)
plot!(k2rf, R_tatf, ls = :solid,c=:purple)
plot!(k2rb, R_tatb, ls = :dash,c=:purple)

# %%
plot(k2rf, R_fdapf, ls = :solid,c=:green)
plot!(k2rb, R_fdapb, ls = :dash,c=:green)
plot!(k2rf, R_fdaf, ls = :solid,c=:orange)
plot!(k2rb, R_fdab, ls = :dash,c=:orange)

# %%
@load "rewiring_3D_Ω_decrease_ID_935888.jld2"

p = plot(k2rf, Rf_nump,ls = :solid,c=:black,label="Num",dpi=300,xlabel="K2/K2crit", ylabel="R2",title = "Rewire N=4k, Decrease, K3=2.0K3crit_rewire")
plot!(k2rb, Rb_nump, ls = :dash,c=:black,label="")
plot!(k2rf, R_tatpf, ls = :solid,c=:red,label="Tat")
plot!(k2rb, R_tatpb, ls = :dash,c=:red,label="")
plot!(k2rf, R_fdapf, ls = :solid,c=:green,label="Fda")
plot!(k2rb, R_fdapb, ls = :dash,c=:green,label="")
savefig("/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_rewire_decrease_n4000_k3_2.5.pdf")
display(p)

# %%
p = plot(k2rf, Rf_num,ls = :solid,c=:black,label="Num",dpi=300,xlabel="K2/K2crit", ylabel="R2",title = "Rewire N=4k, Orig_inc, K3=2.5K3crit_rewire")
plot!(k2rb, Rb_num, ls = :dash,c=:black,label="")
plot!(k2rf, R_tatf, ls = :solid,c=:red,label="Tat")
plot!(k2rb, R_tatb, ls = :dash,c=:red,label="")
plot!(k2rf, R_fdaf, ls = :solid,c=:green,label="Fda")
plot!(k2rb, R_fdab, ls = :dash,c=:green,label="")
savefig("/Users/chku8451/OneDrive - UCB-O365/dissertation/report/pix/kuramoto_orig_decrease_n4000_k3_2.5.pdf")
display(p)
