# %%
using Pkg
Pkg.activate("env")
# Out:
#   Activating project at `~/Library/CloudStorage/OneDrive-UCB-O365/dissertation/high-order-kuramoto/env`

# %%
using Plots, JLD2

# %%
@load "res_n_100_ID_500013.jld2"
# Out:
# 9-element Vector{Symbol}:
#  :k2rf
#  :R_tatf
#  :R_fdaf
#  :Rf_num
#  :k2rb
#  :R_tatb
#  :R_fdab
#  :Rb_num
#  :key_params

# %%
key_params
# Out:
# Dict{String, Real} with 7 entries:
#   "K3Crit"      => 0.0914015
#   "K2Crit"      => 0.124757
#   "Mean_deg"    => 14.48
#   "K3Crit_mean" => 0.0703963
#   "Mean_deg3"   => 14.85
#   "K2Crit_mean" => 0.125108
#   "n"           => 100

# %%
plot(k2rf, Rf_num)
plot!(k2rb, Rb_num)
